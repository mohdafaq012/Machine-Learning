# %% [markdown]
# # 1. Setup and Data Loading

# %% [markdown]
# ## 1.1 Importing Dependencies

# %%
import os
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.neighbors import NearestNeighbors
from annoy import AnnoyIndex
from tensorflow.keras.layers import Input, Embedding, Flatten, Concatenate, Dense
from tensorflow.keras.models import Model

# %% [markdown]
# ## 1.2 Creating Output Directory

# %%
# Create an output directory if it doesn't exist
output_dir = 'output'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %% [markdown]
# ## 1.3 Loading the Datasets

# %%
# Load datasets
users_df = pd.read_csv('users.csv')  # Contains user metadata
interactions_df = pd.read_csv('interactions.csv')  # Contains user interactions
test_df = pd.read_csv('recommendations.csv')  # Contains Member_IDs for recommendations

# %% [markdown]
# # 2. Data Preprocessing

# %% [markdown]
# ## 2.1 Handling Missing and Duplicate values

# %%
# Handle missing values (drop rows with missing data)
users_df.dropna(inplace=True)
interactions_df.dropna(inplace=True)
# Remove duplicates
interactions_df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 2.2 Encoding variables

# %%
# Encode categorical variables (e.g., Gender, Marital_Status, Sect, Caste, State)
categorical_columns = ['Gender', 'Marital_Status', 'Sect', 'Caste', 'State']
label_encoders = {}

for col in categorical_columns:
    le = LabelEncoder()
    users_df[col] = le.fit_transform(users_df[col])
    label_encoders[col] = le  # Save encoders for later use (if needed)

# Normalize numerical features (e.g., Age)
scaler = MinMaxScaler()
users_df['Age'] = scaler.fit_transform(users_df[['Age']])

# %%
# Add an implicit interaction score (1 for all interactions)
interactions_df['Interaction_Score'] = 1

# %% [markdown]
# ## 2.3 Creating User-Item Interaction Matrix

# %%
# Create a user-item interaction matrix
user_ids = interactions_df['Member_ID'].unique()
item_ids = interactions_df['Target_ID'].unique()

# Map Member_ID and Target_ID to indices
user_id_map = {user_id: idx for idx, user_id in enumerate(user_ids)}
item_id_map = {item_id: idx for idx, item_id in enumerate(item_ids)}

# Create a sparse matrix for interactions
row = interactions_df['Member_ID'].map(user_id_map)
col = interactions_df['Target_ID'].map(item_id_map)
data = interactions_df['Interaction_Score']

interaction_matrix = csr_matrix((data, (row, col)), shape=(len(user_ids), len(item_ids)))

# %% [markdown]
# # 3. Collaborative Filtering (Matrix Factorization)

# %%
def collaborative_filtering(interaction_matrix, n_components=50):
    # Perform Singular Value Decomposition (SVD)
    svd = TruncatedSVD(n_components=n_components, random_state=42)
    user_factors = svd.fit_transform(interaction_matrix)
    item_factors = svd.components_.T
    return user_factors, item_factors

# %%
# Perform collaborative filtering
user_factors, item_factors = collaborative_filtering(interaction_matrix)

# %% [markdown]
# # 4. Approximate Nearest Neighbors (ANN)

# %%
def build_ann_index(user_factors, n_trees=10):
    n_users, n_factors = user_factors.shape
    ann_index = AnnoyIndex(n_factors, 'angular')  # Angular distance for cosine similarity
    for i in range(n_users):
        ann_index.add_item(i, user_factors[i])
    ann_index.build(n_trees)
    return ann_index

# %%
# Build ANN index
ann_index = build_ann_index(user_factors)

# %% [markdown]
# # 5. Content-Based Filtering (Metadata Embeddings)

# %% [markdown]
# ## 5.1 Building Neural Network to create Embeddings for User's Metadata

# %%
def build_metadata_embeddings(users_df, embedding_dim=16):
    inputs = []
    embeddings = []
    
    # Create embeddings for each categorical feature
    for col in categorical_columns:
        input_layer = Input(shape=(1,))
        vocab_size = users_df[col].nunique()
        embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim)(input_layer)
        flatten_layer = Flatten()(embedding_layer)
        inputs.append(input_layer)
        embeddings.append(flatten_layer)
    
    # Add numerical feature (Age)
    age_input = Input(shape=(1,))
    embeddings.append(age_input)
    inputs.append(age_input)
    
    # Concatenate all embeddings
    concatenated = Concatenate()(embeddings)
    dense_layer = Dense(64, activation='relu')(concatenated)
    output_layer = Dense(embedding_dim, activation='linear')(dense_layer)
    
    # Build model
    model = Model(inputs, output_layer)
    return model

# %% [markdown]
# ## 5.2 Training the Metadata Embedding Model

# %%
# Train metadata embeddings
metadata_model = build_metadata_embeddings(users_df)
metadata_model.compile(optimizer='adam', loss='mse')

# Prepare metadata inputs for training
metadata_inputs = [users_df[col].values for col in categorical_columns] + [users_df['Age'].values]
metadata_model.fit(metadata_inputs, np.zeros((len(users_df), 16)), epochs=10, batch_size=64)

# Extract metadata embeddings
metadata_embeddings = metadata_model.predict(metadata_inputs)
# Out:
# Epoch 1/10
# 4700/4700 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 9.4161e-06
# Epoch 2/10
# 4700/4700 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 6.8270e-08
# Epoch 3/10
# 4700/4700 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 3.1728e-08
# Epoch 4/10
# 4700/4700 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 1.7084e-08
# Epoch 5/10
# 4700/4700 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 8.7917e-09
# Epoch 6/10
# 4700/4700 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 8.7340e-09
# Epoch 7/10
# 4700/4700 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 4.6571e-10
# Epoch 8/10
# 4700/4700 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 7.6393e-10
# Epoch 9/10
# 4700/4700 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 7.5588e-10
# Epoch 10/10
# 4700/4700 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - loss: 7.2235e-10
# 9399/9399 ━━━━━━━━━━━━━━━━━━━━ 9s 993us/step

# %%
metadata_embeddings
# Out:
# array([[-4.5676948e-06,  8.1007889e-10, -1.6432686e-12, ...,
#          2.5688538e-12, -2.8119444e-11,  2.5953586e-08],
#        [-4.5676948e-06,  8.1007889e-10, -1.6432686e-12, ...,
#          2.5688538e-12, -2.8119444e-11,  2.5953586e-08],
#        [-4.5676948e-06,  8.1007889e-10, -1.6432686e-12, ...,
#          2.5688538e-12, -2.8119444e-11,  2.5953586e-08],
#        ...,
#        [-4.5676948e-06,  8.1007889e-10, -1.6432686e-12, ...,
#          2.5688538e-12, -2.8119444e-11,  2.5953586e-08],
#        [-4.5676948e-06,  8.1007889e-10, -1.6432686e-12, ...,
#          2.5688538e-12, -2.8119444e-11,  2.5953586e-08],
#        [-4.5676948e-06,  8.1007889e-10, -1.6432686e-12, ...,
#          2.5688538e-12, -2.8119444e-11,  2.5953586e-08]], dtype=float32)

# %% [markdown]
# # 6. Metadata-Based Recommendations

# %%
# Step 4: Metadata-Based Recommendations (Fallback)
def metadata_based_recommendations(user_id, users_df, opposite_gender, top_n=100):
    # Get opposite gender profiles
    opposite_profiles = users_df[users_df['Gender'] == opposite_gender]

    # Exclude past interactions (if any)
    past_interactions = interactions_df[(interactions_df['Member_ID'] == user_id) | (interactions_df['Target_ID'] == user_id)]
    interacted_users = set(past_interactions['Member_ID']).union(set(past_interactions['Target_ID']))
    opposite_profiles = opposite_profiles[~opposite_profiles['Member_ID'].isin(interacted_users)]

    # Fallback: Recommend profiles based on metadata similarity (e.g., age, caste, state)
    user_metadata = users_df[users_df['Member_ID'] == user_id].iloc[0]
    opposite_profiles['similarity_score'] = opposite_profiles.apply(
        lambda row: np.dot(
            row[['Age', 'Sect', 'Caste', 'State']].values,
            user_metadata[['Age', 'Sect', 'Caste', 'State']].values
        ), axis=1
    )

    # Sort by similarity score and select top N profiles
    top_n_profiles = opposite_profiles.sort_values(by='similarity_score', ascending=False).head(top_n)['Member_ID'].tolist()
    return top_n_profiles

# %% [markdown]
# # 7. Hybrid Recommendation

# %%
def hybrid_recommendation(user_id, ann_index, user_factors, metadata_embeddings, users_df, interactions_df, top_n=100):
    # Get opposite gender profiles
    user_gender = users_df.loc[users_df['Member_ID'] == user_id, 'Gender'].values[0]
    opposite_gender = 1 if user_gender == 0 else 0  # Assuming 0: Male, 1: Female
    opposite_profiles = users_df[users_df['Gender'] == opposite_gender]

    # Exclude past interactions
    past_interactions = interactions_df[(interactions_df['Member_ID'] == user_id) | (interactions_df['Target_ID'] == user_id)]
    interacted_users = set(past_interactions['Member_ID']).union(set(past_interactions['Target_ID']))
    opposite_profiles = opposite_profiles[~opposite_profiles['Member_ID'].isin(interacted_users)]

    # Get user index
    user_idx = user_id_map.get(user_id, -1)
    if user_idx == -1:
        # Fallback: Use metadata-based recommendations
        return metadata_based_recommendations(user_id, users_df, opposite_gender, top_n)
    
    # Find approximate nearest neighbors (collaborative filtering)
    similar_users = ann_index.get_nns_by_item(user_idx, top_n * 10)  # Fetch more to filter later (AA keep in mind)
    similar_users = [u for u in similar_users if u in opposite_profiles.index]

    # Combine collaborative and content-based scores
    user_metadata_embedding = metadata_embeddings[user_idx]
    content_scores = np.dot(metadata_embeddings[similar_users], user_metadata_embedding)
    collab_scores = [1 / (1 + i) for i in range(len(similar_users))]  # Higher score for closer neighbors
    hybrid_scores = 0.7 * np.array(collab_scores) + 0.3 * content_scores  # Weighted combination

    # Select top N profiles
    top_n_indices = np.argsort(hybrid_scores)[-top_n:][::-1]
    top_n_profiles = opposite_profiles.iloc[top_n_indices]['Member_ID'].tolist()
    return top_n_profiles

# %% [markdown]
# # 8. Generating Recommendations

# %%
def generate_test_recommendations(test_df, ann_index, user_factors, metadata_embeddings, users_df, interactions_df):
    recommendations = []
    for user_id in test_df['Member_ID']:
        top_100_profiles = hybrid_recommendation(user_id, ann_index, user_factors, metadata_embeddings, users_df, interactions_df, top_n=100)
        if not top_100_profiles:  # Fallback: Use metadata-based recommendations
            print(f"No recommendations found for user {user_id}. Using fallback.")
            top_100_profiles = metadata_based_recommendations(user_id, users_df, opposite_gender=1 if users_df.loc[users_df['Member_ID'] == user_id, 'Gender'].values[0] == 0 else 0)
        recommendations.append({'Member_ID': user_id, 'top_100_profiles': ','.join(map(str, top_100_profiles))})
    return pd.DataFrame(recommendations)

# %%
# Generate recommendations for test data
recommendations_df = generate_test_recommendations(test_df, ann_index, user_factors, metadata_embeddings, users_df, interactions_df)

# %% [markdown]
# # 9. Saving Recommendations

# %%
# Save recommendations to CSV in the output directory
output_file_path = os.path.join(output_dir, 'recommendations.csv')
recommendations_df.to_csv(output_file_path, index=False)

# %% [markdown]
# # 10. Showing the Output of the Recommendations

# %%
data1 = pd.read_csv('output/recommendations.csv')

# %%
data1.head()
# Out:
#    Member_ID                                   top_100_profiles
# 0     137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...
# 1      16569  7,38,63,86,121,163,190,248,283,293,316,429,478...
# 2     439283  10,30,246,538,694,725,820,994,1090,1158,1241,1...
# 3     278297  10,30,246,538,694,725,820,994,1090,1158,1241,1...
# 4     121606  6825,258496,443321,287,343239,257198,350520,47...

# %%
for i in range(100):
    profile_list = data1['top_100_profiles'][i].split(',')
    print("Number of profiles:", len(profile_list))
# Out:
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100
# Number of profiles: 100

# %%
import pandas as pd

# Load the recommendations.csv file
recommendations_df = pd.read_csv('output/recommendations.csv')

# Load the users.csv file
users_df = pd.read_csv('users.csv')

# Create a dictionary to map Member_ID to their metadata
user_metadata_dict = users_df.set_index('Member_ID').to_dict(orient='index')

# Function to get metadata for top_100_profiles
def get_top_profiles_metadata(row):
    member_id = row['Member_ID']
    top_100_profiles = row['top_100_profiles'].split(',')  # Split the string into a list of profile IDs
    top_100_profiles = [int(profile_id) for profile_id in top_100_profiles]  # Convert to integers
    
    # Fetch metadata for each profile in top_100_profiles
    profiles_metadata = []
    for profile_id in top_100_profiles:
        if profile_id in user_metadata_dict:
            metadata = user_metadata_dict[profile_id]
            profiles_metadata.append({
                'Profile_ID': profile_id,
                'Gender': metadata['Gender'],
                'Caste': metadata['Caste'],
                'Sect': metadata['Sect'],
                'State': metadata['State']
            })
        else:
            # Handle cases where profile_id is not found in users.csv
            profiles_metadata.append({
                'Profile_ID': profile_id,
                'Gender': 'Unknown',
                'Caste': 'Unknown',
                'Sect': 'Unknown',
                'State': 'Unknown'
            })
    
    return profiles_metadata

# Apply the function to each row in recommendations_df
recommendations_df['top_100_profiles_metadata'] = recommendations_df.apply(get_top_profiles_metadata, axis=1)

# Explode the list of metadata into separate rows
exploded_df = recommendations_df.explode('top_100_profiles_metadata')

# Reset the index of exploded_df to avoid duplicate indices
exploded_df = exploded_df.reset_index(drop=True)

# Normalize the metadata dictionary into separate columns
metadata_df = pd.json_normalize(exploded_df['top_100_profiles_metadata'])

# Combine the metadata with the original recommendations_df
final_df = pd.concat([exploded_df.drop(columns=['top_100_profiles_metadata']), metadata_df], axis=1)

# Display the final result
print(final_df)
# Out:
#        Member_ID                                   top_100_profiles  \
# 0         137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...
# 1         137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...
# 2         137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...
# 3         137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...
# 4         137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...
# ...          ...                                                ...
# 29813      83917  7,38,63,86,121,163,190,248,283,293,316,429,478...
# 29814      83917  7,38,63,86,121,163,190,248,283,293,316,429,478...
# 29815      83917  7,38,63,86,121,163,190,248,283,293,316,429,478...
# 29816      83917  7,38,63,86,121,163,190,248,283,293,316,429,478...
# 29817      83917  7,38,63,86,121,163,190,248,283,293,316,429,478...
#
#        Profile_ID  Gender             Caste   Sect          State
# 0              10  Female  Sheikh or Shaikh  Sunni          Bihar
# 1              30  Female             Other  Sunni          Delhi
# 2             246  Female             Other  Sunni  Uttar Pradesh
# 3             538  Female  Sheikh or Shaikh  Sunni          Delhi
# 4             694  Female    Khan or Pathan  Sunni  Uttar Pradesh
# ...           ...     ...               ...    ...            ...
# 29813        6053    Male             Other  Sunni  Uttar Pradesh
# 29814        6107    Male    Khan or Pathan  Sunni  Uttar Pradesh
# 29815        6222    Male    Khan or Pathan  Sunni          Bihar
# 29816        6246    Male    Khan or Pathan  Sunni  Uttar Pradesh
# 29817        6310    Male              Syed  Sunni  Uttar Pradesh
#
# [29818 rows x 7 columns]

# %%
final_df.head()
# Out:
#    Member_ID                                   top_100_profiles  Profile_ID  \
# 0     137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...          10
# 1     137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...          30
# 2     137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...         246
# 3     137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...         538
# 4     137544  10,30,246,538,694,725,820,994,1090,1158,1241,1...         694
#
#    Gender             Caste   Sect          State
# 0  Female  Sheikh or Shaikh  Sunni          Bihar
# 1  Female             Other  Sunni          Delhi
# 2  Female             Other  Sunni  Uttar Pradesh
# 3  Female  Sheikh or Shaikh  Sunni          Delhi
# 4  Female    Khan or Pathan  Sunni  Uttar Pradesh

# %%
import pandas as pd

# Load the recommendations.csv file
recommendations_df = pd.read_csv('output/recommendations.csv')

# Load the users.csv file
users_df = pd.read_csv('users.csv')

# Create a dictionary to map Member_ID to their metadata
user_metadata_dict = users_df.set_index('Member_ID').to_dict(orient='index')

# Initialize the final nested dictionary
nested_dict = {}

# Function to get metadata for top_100_profiles
def get_top_profiles_metadata(row):
    member_id = row['Member_ID']
    top_100_profiles = row['top_100_profiles'].split(',')  # Split the string into a list of profile IDs
    top_100_profiles = [int(profile_id) for profile_id in top_100_profiles]  # Convert to integers
    
    # Fetch metadata for each profile in top_100_profiles
    profiles_metadata = {}
    for profile_id in top_100_profiles:
        if profile_id in user_metadata_dict:
            metadata = user_metadata_dict[profile_id]
            profiles_metadata[profile_id] = {
                'Age': metadata['Age'],
                'Gender': metadata['Gender'],
                'Caste': metadata['Caste'],
                'Sect': metadata['Sect'],
                'State': metadata['State']
            }
        else:
            # Handle cases where profile_id is not found in users.csv
            profiles_metadata[profile_id] = {
                'Age': 'Unknown',
                'Gender': 'Unknown',
                'Caste': 'Unknown',
                'Sect': 'Unknown',
                'State': 'Unknown'
            }
    
    return profiles_metadata

# Populate the nested dictionary
for _, row in recommendations_df.iterrows():
    member_id = row['Member_ID']
    nested_dict[member_id] = get_top_profiles_metadata(row)

# Display the nested dictionary
for member_id, profiles in nested_dict.items():
    print(f"Member_ID: {member_id}")
    for profile_id, details in profiles.items():
        print(f"  Profile_ID: {profile_id}, Details: {details}")
    print()

# Save the nested dictionary to a JSON file (optional)
import json
with open('output1/nested_dict.json', 'w') as f:
    json.dump(nested_dict, f, indent=4)
# Out:
# Member_ID: 137544
#   Profile_ID: 10, Details: {'Age': 25, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 30, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 246, Details: {'Age': 44, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 538, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 694, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 725, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 820, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 994, Details: {'Age': 40, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1090, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1158, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 1241, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1242, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 1852, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1984, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 2000, Details: {'Age': 40, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2118, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2189, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 2395, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2731, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3023, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3253, Details: {'Age': 25, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 3345, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3378, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3504, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3751, Details: {'Age': 35, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3764, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3890, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3972, Details: {'Age': 41, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4060, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4419, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4539, Details: {'Age': 41, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 4641, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4665, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4721, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4774, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4817, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 5446, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Karnataka'}
#   Profile_ID: 5455, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 5582, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 5780, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 6074, Details: {'Age': 49, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 6108, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6190, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6968, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7069, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7072, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7078, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7207, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7228, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7345, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7376, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7534, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7600, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7721, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7869, Details: {'Age': 43, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7874, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7943, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7962, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7963, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8005, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8172, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 8256, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8274, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8308, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8309, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8324, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8482, Details: {'Age': 23, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8880, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9024, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 9041, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9225, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9334, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 9446, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9454, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9468, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 9522, Details: {'Age': 58, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9541, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9705, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9727, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9881, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9898, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9983, Details: {'Age': 35, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10039, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10075, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 10110, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10220, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10319, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 10339, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10359, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10376, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 10514, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 10536, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10613, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10782, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10826, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11021, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 11077, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11136, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11149, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11194, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#
# Member_ID: 16569
#   Profile_ID: 7, Details: {'Age': 27, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 38, Details: {'Age': 33, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 63, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 86, Details: {'Age': 31, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 121, Details: {'Age': 39, 'Gender': 'Male', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 163, Details: {'Age': 33, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 190, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 248, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 283, Details: {'Age': 33, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 293, Details: {'Age': 33, 'Gender': 'Male', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 316, Details: {'Age': 38, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 429, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 478, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 752, Details: {'Age': 36, 'Gender': 'Male', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 760, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 905, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 909, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1088, Details: {'Age': 30, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1151, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1178, Details: {'Age': 36, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1206, Details: {'Age': 31, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1225, Details: {'Age': 36, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1550, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1579, Details: {'Age': 42, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1582, Details: {'Age': 40, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1693, Details: {'Age': 26, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1711, Details: {'Age': 46, 'Gender': 'Male', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1785, Details: {'Age': 31, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1789, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1879, Details: {'Age': 31, 'Gender': 'Male', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1899, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1980, Details: {'Age': 36, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1993, Details: {'Age': 38, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 2036, Details: {'Age': 43, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2109, Details: {'Age': 30, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2141, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2158, Details: {'Age': 39, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2198, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 2316, Details: {'Age': 41, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Shia', 'State': 'Bihar'}
#   Profile_ID: 2349, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 2467, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 2622, Details: {'Age': 42, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2722, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 2763, Details: {'Age': 31, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 2764, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Karnataka'}
#   Profile_ID: 2783, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 2789, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 2820, Details: {'Age': 50, 'Gender': 'Male', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2940, Details: {'Age': 36, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2943, Details: {'Age': 33, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3029, Details: {'Age': 37, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3090, Details: {'Age': 31, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3248, Details: {'Age': 30, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3354, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Other', 'Sect': 'Shia', 'State': 'Delhi'}
#   Profile_ID: 3356, Details: {'Age': 37, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3383, Details: {'Age': 37, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3441, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 3506, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3593, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3659, Details: {'Age': 33, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3762, Details: {'Age': 40, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3828, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3834, Details: {'Age': 38, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3873, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 3997, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 4058, Details: {'Age': 41, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 4093, Details: {'Age': 31, 'Gender': 'Male', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4109, Details: {'Age': 29, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4212, Details: {'Age': 37, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4233, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4253, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4272, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4278, Details: {'Age': 41, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 4456, Details: {'Age': 31, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4582, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4701, Details: {'Age': 29, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4743, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4747, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4789, Details: {'Age': 30, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4814, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 4820, Details: {'Age': 30, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 4863, Details: {'Age': 33, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4879, Details: {'Age': 29, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4939, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 5021, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 5230, Details: {'Age': 59, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 5344, Details: {'Age': 28, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 5656, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 5723, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 5740, Details: {'Age': 30, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 5747, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Karnataka'}
#   Profile_ID: 5766, Details: {'Age': 32, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 5860, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 5888, Details: {'Age': 29, 'Gender': 'Male', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 6013, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6053, Details: {'Age': 29, 'Gender': 'Male', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6107, Details: {'Age': 38, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6222, Details: {'Age': 35, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 6246, Details: {'Age': 30, 'Gender': 'Male', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6310, Details: {'Age': 34, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#
# Member_ID: 439283
#   Profile_ID: 10, Details: {'Age': 25, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 30, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 246, Details: {'Age': 44, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 538, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 694, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 725, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 820, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 994, Details: {'Age': 40, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1090, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1158, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 1241, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1242, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 1852, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1984, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 2000, Details: {'Age': 40, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2118, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2189, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 2395, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2731, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3023, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3253, Details: {'Age': 25, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 3345, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3378, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3504, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3751, Details: {'Age': 35, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3764, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3890, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3972, Details: {'Age': 41, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4060, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4419, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4539, Details: {'Age': 41, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 4641, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4665, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4721, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4774, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4817, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 5446, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Karnataka'}
#   Profile_ID: 5455, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 5582, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 5780, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 6074, Details: {'Age': 49, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 6108, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6190, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6968, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7069, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7072, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7078, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7207, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7228, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7345, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7376, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7534, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7600, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7721, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7869, Details: {'Age': 43, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7874, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7943, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7962, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7963, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8005, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8172, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 8256, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8274, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8308, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8309, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8324, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8482, Details: {'Age': 23, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8880, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9024, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 9041, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9225, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9334, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 9446, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9454, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9468, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 9522, Details: {'Age': 58, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9541, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9705, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9727, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9881, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9898, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9983, Details: {'Age': 35, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10039, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10075, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 10110, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10220, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10319, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 10339, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10359, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10376, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 10514, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 10536, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10613, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10782, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10826, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11021, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 11077, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11136, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11149, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11194, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#
# Member_ID: 278297
#   Profile_ID: 10, Details: {'Age': 25, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 30, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 246, Details: {'Age': 44, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 538, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 694, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 725, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 820, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 994, Details: {'Age': 40, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1090, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1158, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 1241, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1242, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 1852, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 1984, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 2000, Details: {'Age': 40, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2118, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2189, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 2395, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 2731, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3023, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3253, Details: {'Age': 25, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 3345, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3378, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3504, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3751, Details: {'Age': 35, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3764, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3890, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3972, Details: {'Age': 41, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4060, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4419, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4539, Details: {'Age': 41, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 4641, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4665, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4721, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4774, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4817, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 5446, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Karnataka'}
#   Profile_ID: 5455, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 5582, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 5780, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 6074, Details: {'Age': 49, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 6108, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6190, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6968, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7069, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7072, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7078, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7207, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7228, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7345, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7376, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7534, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7600, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7721, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7869, Details: {'Age': 43, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7874, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7943, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7962, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7963, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8005, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8172, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 8256, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8274, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8308, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8309, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8324, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8482, Details: {'Age': 23, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8880, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9024, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 9041, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9225, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9334, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 9446, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9454, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9468, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 9522, Details: {'Age': 58, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9541, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9705, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9727, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9881, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9898, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9983, Details: {'Age': 35, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10039, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10075, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 10110, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10220, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10319, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
# ...
#   Profile_ID: 3023, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3253, Details: {'Age': 25, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 3345, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3378, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3504, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3751, Details: {'Age': 35, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3764, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3890, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 3972, Details: {'Age': 41, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4060, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4419, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4539, Details: {'Age': 41, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 4641, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4665, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4721, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4774, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 4817, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 5446, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Karnataka'}
#   Profile_ID: 5455, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 5582, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 5780, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 6074, Details: {'Age': 49, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 6108, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6190, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6968, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7069, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7072, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7078, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7207, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7228, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7345, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 7376, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7534, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7600, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7721, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7869, Details: {'Age': 43, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7874, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 7943, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Shia', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7962, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7963, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8005, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8172, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 8256, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8274, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 8308, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8309, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8324, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8482, Details: {'Age': 23, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8880, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9024, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 9041, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9225, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9334, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 9446, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9454, Details: {'Age': 39, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9468, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 9522, Details: {'Age': 58, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9541, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9705, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9727, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9881, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 9898, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 9983, Details: {'Age': 35, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10039, Details: {'Age': 38, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10075, Details: {'Age': 27, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 10110, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10220, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10319, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 10339, Details: {'Age': 31, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10359, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10376, Details: {'Age': 34, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Maharashtra'}
#   Profile_ID: 10514, Details: {'Age': 29, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Bihar'}
#   Profile_ID: 10536, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10613, Details: {'Age': 33, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10782, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'Other', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10826, Details: {'Age': 30, 'Gender': 'Female', 'Caste': 'Sheikh or Shaikh', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11021, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Ansari', 'Sect': 'Sunni', 'State': 'Delhi'}
#   Profile_ID: 11077, Details: {'Age': 28, 'Gender': 'Female', 'Caste': 'Khan or Pathan', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11136, Details: {'Age': 36, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11149, Details: {'Age': 32, 'Gender': 'Female', 'Caste': 'No Caste', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 11194, Details: {'Age': 26, 'Gender': 'Female', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Delhi'}
#
# Member_ID: 11487
#   Profile_ID: 9119, Details: {'Age': 67, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 160373, Details: {'Age': 66, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 8303, Details: {'Age': 65, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 376487, Details: {'Age': 63, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 176129, Details: {'Age': 62, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 460382, Details: {'Age': 61, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 443275, Details: {'Age': 60, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 74911, Details: {'Age': 60, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 281801, Details: {'Age': 59, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 415783, Details: {'Age': 59, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 5265, Details: {'Age': 58, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7996, Details: {'Age': 58, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 195619, Details: {'Age': 58, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 370716, Details: {'Age': 58, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 401844, Details: {'Age': 58, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 444140, Details: {'Age': 58, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 343401, Details: {'Age': 57, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 72385, Details: {'Age': 56, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 449910, Details: {'Age': 55, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 115694, Details: {'Age': 55, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 23799, Details: {'Age': 55, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 258117, Details: {'Age': 55, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 179566, Details: {'Age': 55, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 367024, Details: {'Age': 55, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 3258, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 328310, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 406997, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 5356, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 129422, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 10455, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 127434, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 195885, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 190386, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 7103, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 335612, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 316493, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 202137, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 398563, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 415793, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 162147, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 324327, Details: {'Age': 54, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 6511, Details: {'Age': 53, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 210989, Details: {'Age': 53, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 1189, Details: {'Age': 53, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
#   Profile_ID: 372747, Details: {'Age': 53, 'Gender': 'Male', 'Caste': 'Syed', 'Sect': 'Sunni', 'State': 'Uttar Pradesh'}
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
